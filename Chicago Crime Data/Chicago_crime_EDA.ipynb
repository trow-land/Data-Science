# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\tom_r\Downloads\Crimes_-_2001_to_Present_20250402.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8285876 entries, 0 to 8285875
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# ...

# %%
df.head()
# Out:
#          ID Case Number                    Date                    Block  \
# 0  13311263    JG503434  07/29/2022 03:39:00 AM          023XX S TROY ST
# 1  13053066    JG103252  01/03/2023 04:44:00 PM  039XX W WASHINGTON BLVD
# 2  11227634    JB147599  08/26/2017 10:00:00 AM      001XX W RANDOLPH ST
# 3  13203321    JG415333  09/06/2023 05:00:00 PM         002XX N Wells st
# 4  13204489    JG416325  09/06/2023 11:00:00 AM           0000X E 8TH ST
#
#    IUCR                Primary Type                    Description  \
# 0  1582  OFFENSE INVOLVING CHILDREN              CHILD PORNOGRAPHY
# 1  2017                   NARCOTICS  MANUFACTURE / DELIVER - CRACK
# 2  0281         CRIM SEXUAL ASSAULT                 NON-AGGRAVATED
# 3  1320             CRIMINAL DAMAGE                     TO VEHICLE
# 4  0810                       THEFT                      OVER $500
#
#                      Location Description  Arrest  Domestic  ...  Ward  \
# ...

# %%
df['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                1756378
# BATTERY                              1509789
# CRIMINAL DAMAGE                       942492
# NARCOTICS                             759790
# ASSAULT                               551492
# OTHER OFFENSE                         515930
# BURGLARY                              439744
# MOTOR VEHICLE THEFT                   420993
# DECEPTIVE PRACTICE                    378865
# ROBBERY                               311142
# CRIMINAL TRESPASS                     223692
# WEAPONS VIOLATION                     121649
# PROSTITUTION                           70301
# OFFENSE INVOLVING CHILDREN             59394
# PUBLIC PEACE VIOLATION                 54144
# SEX OFFENSE                            33393
# CRIM SEXUAL ASSAULT                    27352
# INTERFERENCE WITH PUBLIC OFFICER       19695
# LIQUOR LAW VIOLATION                   15275
# GAMBLING                               14653
# ...

# %%
df['Description'].value_counts()
# Out:
# Description
# SIMPLE                                               972695
# $500 AND UNDER                                       667349
# DOMESTIC BATTERY SIMPLE                              647304
# TO VEHICLE                                           463861
# OVER $500                                            450662
#                                                       ...
# KEEP PLACE OF JUV PROSTITUTION                            1
# THEFT RETAIL                                              1
# FINANCIAL IDENTITY THEFT: $300 & UNDER                    1
# AGGRAVATED: HANDS / FIST / FEET NO / MINOR INJURY         1
# KEEPING PLACE OF PROSTITUTION                             1
# Name: count, Length: 573, dtype: int64

# %%
# make column names sql friendly
df.columns = [col.lower().replace(" ", "_") for col in df.columns]

# %%
df.columns.values
# Out:
# array(['id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic',
#        'beat', 'district', 'ward', 'community_area', 'fbi_code',
#        'x_coordinate', 'y_coordinate', 'year', 'updated_on', 'latitude',
#        'longitude', 'location'], dtype=object)

# %%
# convert date columns
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#          id case_number                date                    block  iucr  \
# 0  13311263    JG503434 2022-07-29 03:39:00          023XX S TROY ST  1582
# 1  13053066    JG103252 2023-01-03 16:44:00  039XX W WASHINGTON BLVD  2017
# 2  11227634    JB147599 2017-08-26 10:00:00      001XX W RANDOLPH ST  0281
# 3  13203321    JG415333 2023-09-06 17:00:00         002XX N Wells st  1320
# 4  13204489    JG416325 2023-09-06 11:00:00           0000X E 8TH ST  0810
#
#                  primary_type                    description  \
# 0  OFFENSE INVOLVING CHILDREN              CHILD PORNOGRAPHY
# 1                   NARCOTICS  MANUFACTURE / DELIVER - CRACK
# 2         CRIM SEXUAL ASSAULT                 NON-AGGRAVATED
# 3             CRIMINAL DAMAGE                     TO VEHICLE
# 4                       THEFT                      OVER $500
#
#                      location_description  arrest  domestic  ...  ward  \
# 0                               RESIDENCE    True     False  ...  25.0
# ...

# %%
df['beat']
# Out:
# 0          1033
# 1          1122
# 2           122
# 3           122
# 4           123
#            ...
# 8285871    1424
# 8285872     132
# 8285873    2535
# 8285874    1925
# 8285875    1223
# Name: beat, Length: 8285876, dtype: int64

# %%
# strip unwanted column

wanted_columns = ['id', 'case_number', 'date', 'block', 'primary_type',
       'description', 'location_description', 'arrest', 'domestic',
       'beat', 'district', 'ward', 'community_area', 
       'x_coordinate', 'y_coordinate', 'year', 'updated_on', 'latitude',
       'longitude', 'location']

df = df[wanted_columns].copy()

# %%
df
# Out:
#                id case_number                date                    block  \
# 0        13311263    JG503434 2022-07-29 03:39:00          023XX S TROY ST
# 1        13053066    JG103252 2023-01-03 16:44:00  039XX W WASHINGTON BLVD
# 2        11227634    JB147599 2017-08-26 10:00:00      001XX W RANDOLPH ST
# 3        13203321    JG415333 2023-09-06 17:00:00         002XX N Wells st
# 4        13204489    JG416325 2023-09-06 11:00:00           0000X E 8TH ST
# ...           ...         ...                 ...                      ...
# 8285871  13786420    JJ194332 2025-03-24 18:45:00    015XX N MILWAUKEE AVE
# 8285872  13785709    JJ194066 2025-03-24 04:30:00          003XX E 21ST ST
# 8285873  13790202    JJ199106 2025-03-22 10:15:00     036XX W WABANSIA AVE
# 8285874  13785321    JJ193561 2025-03-24 17:34:00        006XX W ROSCOE ST
# 8285875  13784967    JJ192918 2025-03-24 09:45:00       023XX W MADISON ST
#
# ...
